# %% [markdown]
# ## Optimized Trained TensorFlow Model with NVIDIA Tensor RT

# %% [markdown]
# In this notebook we show how to import a frozen TensorFlow graph, and use the Tensor RT to optimize it and create a runtime engine

# %%
''' Import TensorRT Modules '''
import tensorrt as trt

# %%
import uff
from tensorrt.parsers import uffparser

''' Import other modules '''
import glob

# %%
G_LOGGER = trt.infer.ConsoleLogger(trt.infer.LogSeverity.INFO)

# %%
# Load your newly created Tensorflow frozen model and convert it to UFF
uff_model = uff.from_tensorflow_frozen_model("keras_vgg19_frozen_graph.pb", 
                                             ["dense_2/Softmax"])
# Out:
# Using output node dense_2/Softmax
# Converting to UFF graph
# Warning: keepdims is ignored by the UFF Parser and defaults to True
# No. nodes: 98

# %%
import tensorflow as tf

def printTensors(pb_file):

    # read pb into graph_def
    with tf.gfile.GFile(pb_file, "rb") as f:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(f.read())

    # import graph_def
    with tf.Graph().as_default() as graph:
        tf.import_graph_def(graph_def)

    # print operations
    for op in graph.get_operations():
        print(op.name)

# %%
printTensors("keras_vgg19_frozen_graph.pb")
# Out:
# import/input_1
# import/block1_conv1/kernel
# import/block1_conv1/bias
# import/block1_conv1/convolution
# import/block1_conv1/BiasAdd
# import/block1_conv1/Relu
# import/block1_conv2/kernel
# import/block1_conv2/bias
# import/block1_conv2/convolution
# import/block1_conv2/BiasAdd
# import/block1_conv2/Relu
# import/block1_pool/MaxPool
# import/block2_conv1/kernel
# import/block2_conv1/bias
# import/block2_conv1/convolution
# import/block2_conv1/BiasAdd
# import/block2_conv1/Relu
# import/block2_conv2/kernel
# import/block2_conv2/bias
# import/block2_conv2/convolution
# import/block2_conv2/BiasAdd
# import/block2_conv2/Relu
# import/block2_pool/MaxPool
# import/block3_conv1/kernel
# import/block3_conv1/bias
# import/block3_conv1/convolution
# import/block3_conv1/BiasAdd
# import/block3_conv1/Relu
# import/block3_conv2/kernel
# import/block3_conv2/bias
# import/block3_conv2/convolution
# import/block3_conv2/BiasAdd
# import/block3_conv2/Relu
# import/block3_conv3/kernel
# import/block3_conv3/bias
# import/block3_conv3/convolution
# import/block3_conv3/BiasAdd
# import/block3_conv3/Relu
# import/block3_conv4/kernel
# import/block3_conv4/bias
# import/block3_conv4/convolution
# import/block3_conv4/BiasAdd
# import/block3_conv4/Relu
# import/block3_pool/MaxPool
# import/block4_conv1/kernel
# import/block4_conv1/bias
# import/block4_conv1/convolution
# import/block4_conv1/BiasAdd
# import/block4_conv1/Relu
# import/block4_conv2/kernel
# import/block4_conv2/bias
# import/block4_conv2/convolution
# import/block4_conv2/BiasAdd
# import/block4_conv2/Relu
# import/block4_conv3/kernel
# import/block4_conv3/bias
# import/block4_conv3/convolution
# import/block4_conv3/BiasAdd
# import/block4_conv3/Relu
# import/block4_conv4/kernel
# import/block4_conv4/bias
# import/block4_conv4/convolution
# import/block4_conv4/BiasAdd
# import/block4_conv4/Relu
# import/block4_pool/MaxPool
# import/block5_conv1/kernel
# import/block5_conv1/bias
# import/block5_conv1/convolution
# import/block5_conv1/BiasAdd
# import/block5_conv1/Relu
# import/block5_conv2/kernel
# import/block5_conv2/bias
# import/block5_conv2/convolution
# import/block5_conv2/BiasAdd
# import/block5_conv2/Relu
# import/block5_conv3/kernel
# import/block5_conv3/bias
# import/block5_conv3/convolution
# import/block5_conv3/BiasAdd
# import/block5_conv3/Relu
# import/block5_conv4/kernel
# import/block5_conv4/bias
# import/block5_conv4/convolution
# import/block5_conv4/BiasAdd
# import/block5_conv4/Relu
# import/block5_pool/MaxPool
# import/global_average_pooling2d_1/Mean/reduction_indices
# import/global_average_pooling2d_1/Mean
# import/dense_1/kernel
# import/dense_1/bias
# import/dense_1/MatMul
# import/dense_1/BiasAdd
# import/dense_1/Relu
# import/dense_2/kernel
# import/dense_2/bias
# import/dense_2/MatMul
# import/dense_2/BiasAdd
# import/dense_2/Softmax

# %%
# Create a UFF parser to parse the UFF file created from your TF Frozen model
parser = uffparser.create_uff_parser()
parser.register_input(#input layer, (3,224,224),0) #TODO1
parser.register_output(#output layer)   #TODO2
# Out:
# True

# %%
#TODO3
#Create Engine
engine = trt.utils.uff_to_trt_engine(#logger,#model,#batch_size,1<<20,data_type)

# %%
trt.utils.write_engine_to_file("keras_vgg19_b1_FP32.engine", 
                               engine.serialize())

# %%
glob.glob("*.engine")
# Out:
# ['keras_vgg19_b1_FP32.engine']
